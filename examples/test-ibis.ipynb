# %%
docker run --rm -e CLICKHOUSE_USER=luntaixia -e CLICKHOUSE_DEFAULT_ACCESS_MANAGEMENT=1 -e CLICKHOUSE_PASSWORD=luntaixia -p 9000:9000 -p 8123:8123 -v "/home/luntaixia/Downloads/docker-volume-mapping/playground/clickhouse-storage/logs:/var/log/clickhouse-server" -v "/home/luntaixia/Downloads/docker-volume-mapping/playground/clickhouse-storage/data:/var/lib/clickhouse" -v "/home/luntaixia/Downloads/docker-volume-mapping/playground/clickhouse-storage/configs/users.d:/etc/clickhouse-server/users.d" --ulimit nofile=262144:262144 clickhouse/clickhouse-server

# %%
import ibis
ibis.options.interactive = True

# %%
con = ibis.clickhouse.connect(
    user="default",
    password="luntaixia",
    host="localhost",
    port=8123
)

# %%
con = ibis.connect("clickhouse://play:clickhouse@play.clickhouse.com:443?secure=True")

# %%
actors = con.table("actors")
actors
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ login            ┃ type    ┃ site_admin ┃ name         ┃ company             ┃ blog                ┃ location          ┃ email                     ┃ hireable ┃ bio                                       ┃ twitter_username ┃ public_repos ┃ public_gists ┃ followers ┃ following ┃ created_at          ┃ updated_at          ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ !string          │ !string │ !boolean   │ !string      │ !string             │ !string             │ !string           │ !string                   │ !boolean │ !string                                   │ !string          │ !int64       │ !int64       │ !int64    │ !int64    │ !timestamp(0)       │ !timestamp(0)       │
# ├──────────────────┼─────────┼────────────┼──────────────┼─────────────────────┼─────────────────────┼───────────────────┼───────────────────────────┼──────────┼───────────────────────────────────────────┼──────────────────┼──────────────┼──────────────┼───────────┼───────────┼─────────────────────┼─────────────────────┤
# │ 0000Blaze        │ User    │ False      │ RohanChhetry │ Pulchowk Campus,IOE │ rohanchhetry.com.np │ Sanepa , Lalitpur │ ~                         │ True     │ ~                                         │ rohanchhetry9    │           56 │            0 │        57 │        83 │ 2019-02-24 02:31:21 │ 2023-07-30 11:30:14 │
# │ 007developforfun │ User    │ False      │ ~            │ ~                   │ ~                   │ ~                 │ ~                         │ False    │ ~                                         │ ~                │            0 │            0 │         0 │         0 │ 2015-08-07 11:28:01 │ 2022-08-12 08:45:30 │
# │ 00arthur00       │ User    │ False      │ Arthur       │ ~                   │ ~                   │ Beijing, China    │ yang_yapo@126.com         │ False    │ ~                                         │ ~                │           72 │            1 │         5 │        61 │ 2017-04-01 13:37:01 │ 2023-06-15 14:50:12 │
# │ 010001           │ User    │ False      │ ~            │ ~                   │ ~                   │ ~                 │ 1025394547@qq.com         │ False    │ ~                                         │ ~                │           15 │            0 │         1 │         1 │ 2015-02-05 03:11:59 │ 2023-03-17 06:07:01 │
# │ 01001101ilad     │ User    │ False      │ Milad        │ ~                   │ ~                   │ ~                 │ ~                         │ False    │ Programmer, Writer and Full-Time Learner. │ ~                │           10 │            0 │         0 │         0 │ 2016-10-31 19:12:55 │ 2023-07-24 11:43:03 │
# │ 010227leo        │ User    │ False      │ zucker       │ trip.com            │ ~                   │ Shanghai, China   │ ~                         │ False    │ ~                                         │ ~                │            2 │            1 │         7 │        11 │ 2012-01-11 06:23:15 │ 2023-07-24 03:35:26 │
# │ 010ric           │ User    │ False      │ Mario Turic  │ ~                   │ ~                   │ Munich            │ ~                         │ True     │ Enthusiast and Maker                      │ ~                │           19 │            0 │        23 │        68 │ 2017-10-27 14:00:07 │ 2023-08-04 18:44:35 │
# │ 01egen           │ User    │ False      │ ~            │ ~                   │ ~                   │ ~                 │ ~                         │ False    │ ~                                         │ ~                │            1 │            0 │         0 │         2 │ 2019-02-27 08:59:00 │ 2023-06-20 04:02:51 │
# │ 0400H            │ User    │ False      │ 0400H        │ ~                   │ ~                   │ Shanghai          │ git@0400h.cn              │ True     │ HPC & MLSys & PPML                        │ ~                │           17 │            0 │         3 │        42 │ 2015-12-20 17:38:00 │ 2023-07-21 11:28:22 │
# │ 0442A403         │ User    │ False      │ Damir Petrov │ ~                   │ ~                   │ Moscow            │ petrovdamir2235@gmail.com │ False    │ HSE student                               │ ~                │           19 │            0 │        15 │        30 │ 2016-11-05 18:59:38 │ 2023-06-22 06:08:50 │
# │ …                │ …       │ …          │ …            │ …                   │ …                   │ …                 │ …                         │ …        │ …                                         │ …                │            … │            … │         … │         … │ …                   │ …                   │
# └──────────────────┴─────────┴────────────┴──────────────┴─────────────────────┴─────────────────────┴───────────────────┴───────────────────────────┴──────────┴───────────────────────────────────────────┴──────────────────┴──────────────┴──────────────┴───────────┴───────────┴─────────────────────┴─────────────────────┘

# %%
con.list_tables(like = 'b', database = 'b')
# Out:
# []

# %%
con.list_databases(like = 'RAW')
# Out:
# ['RAW']

# %%
con.create_database('default', force = True)

# %%
con.get_schema("test")
# Out:
# ibis.Schema {
#   name     !string
#   snap_dt  timestamp('Europe/London', 0)
#   history  !array<!int32>
# }

# %%
df.dtypes
# Out:
# NAME                      object
# GENDER                    object
# PHONE                     object
# EMAIL                     object
# BLOOD_GRP                 object
# JOB                       object
# ADDRESS                   object
# CUST_ID                    int64
# OFFICE                    object
# ORG                       object
# TITLE                     object
# SALARY                     int64
# BONUS                      int64
# BIRTH_DT     datetime64[ns, UTC]
# SINCE_DT     datetime64[ns, UTC]
# SNAP_DT      datetime64[ns, UTC]
# dtype: object

# %%
import pandas as pd

df: pd.DataFrame = s3a.read_parquet("/fake/data/FEATURES/CUST/CUST_2024-01-01.parquet")
df['NAME'] = df['NAME'].astype('string')
schema_ = []
for n, t in zip(df.columns, df.dtypes):
    # https://numpy.org/doc/stable/reference/generated/numpy.dtype.kind.html
    if t.kind == 'O':
        schema_.append((n, ibis.expr.datatypes.String()))
    else:
        schema_.append((n, ibis.dtype(t)))
schema(schema_)
# Out:
# ibis.Schema {
#   NAME       string
#   GENDER     string
#   PHONE      string
#   EMAIL      string
#   BLOOD_GRP  string
#   JOB        string
#   ADDRESS    string
#   CUST_ID    int64
#   OFFICE     string
#   ORG        string
#   TITLE      string
#   SALARY     int64
#   BONUS      int64
#   BIRTH_DT   timestamp('UTC')
#   SINCE_DT   timestamp('UTC')
#   SNAP_DT    timestamp('UTC')
# }

# %%
dtypes = df.select_dtypes(exclude = 'object').dtypes
# Out:
# [('CUST_ID', dtype('int64')),
#  ('SALARY', dtype('int64')),
#  ('BONUS', dtype('int64')),
#  ('BIRTH_DT', datetime64[ns, UTC]),
#  ('SINCE_DT', datetime64[ns, UTC]),
#  ('SNAP_DT', datetime64[ns, UTC])]

# %%
Schema.from_pandas(list(zip(dtypes.index, dtypes.values)))
# Out:
# ibis.Schema {
#   CUST_ID   int64
#   SALARY    int64
#   BONUS     int64
#   BIRTH_DT  timestamp('UTC')
#   SINCE_DT  timestamp('UTC')
#   SNAP_DT   timestamp('UTC')
# }

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
from luntaiDs.ProviderTools.clickhouse.dbapi import ClickHouse
from luntaiDs.ProviderTools.clickhouse.snap_struct import SnapshotDataManagerCHSQL

# %%
ch_conf=ClickHouse()
ch_conf.bindServer('localhost', 8123)
ch_conf.login('default', 'luntaixia')
SnapshotDataManagerCHSQL.setup(db_conf=ch_conf)

ch = SnapshotDataManagerCHSQL(
    schema = 'RAW',
    table = 'CUST',
    snap_dt_key = 'SNAP_DT'
)

# %%
from ibis import schema
from ibis.expr.datatypes import String, Timestamp, Array, Int32, Int64, Date, Decimal, Float32

# schema_ = schema(pairs = [
#     ('CUST_ID', Int64(nullable = False)),
#     ('SNAP_DT', Date(nullable = False)),
#     ('NAME', String(nullable = False)),
#     ('GENDER', String(nullable = False)),
#     ('BIRTH_DT', Date(nullable = True)),
#     ('PHONE', String(nullable = True)),
#     ('EMAIL', String(nullable = True)),
#     ('BLOOD_GRP', String(nullable = True)),
#     ('JOB', String(nullable = True)),
#     ('OFFICE', String(nullable = True)),
#     ('ADDRESS', String(nullable = True)),
#     ('ORG', String(nullable = True)),
#     ('TITLE', String(nullable = True)),
#     ('SINCE_DT', Date(nullable = True)),
#     ('SALARY', Float32(nullable = True)),
#     ('BONUS', Float32(nullable = True)),
# ])

ch.init_table(
    col_schemas = ds
)

# %%
from luntaiDs.ProviderTools.aws.s3 import S3Accessor
from datetime import date

s3a = S3Accessor(
    aws_access_key_id='luntaixiaadmin',
    aws_secret_access_key='luntaixiaadmin',
    endpoint_url = 'http://tnas-3991.local:9000'
)
s3a.enter_bucket('general-clf-pipeline-project')

df = s3a.read_parquet("/fake/data/FEATURES/CUST/CUST_2024-01-01.parquet")
#ch.save(df, snap_dt=date(2024,1,1))

# %%
df = s3a.read_parquet("/fake/data/FEATURES/CUST/CUST_2024-01-02.parquet")
ch.save(df, snap_dt=date(2024,1,2))

# %%
ch.disk_space(date(2024,1,2))
# Out:
# 0.880030632019043

# %%
ch.reads([date(2024,1,1), date(2024,1,2)])
# Out:
#            CUST_ID     SNAP_DT                  NAME GENDER    BIRTH_DT  \
# 0          3487385  2024-01-01         Brittany Diaz      F  1980-01-16
# 1          3783703  2024-01-01       Candice Russell      F  1990-08-06
# 2         14173852  2024-01-01         William Olson      M  1988-04-25
# 3         15122648  2024-01-01  Mr. Timothy Anderson      M  1994-06-29
# 4         18329736  2024-01-01          Shelly Davis      F  1977-06-24
# ...            ...         ...                   ...    ...         ...
# 20044  28136838373  2024-01-02           Julie Davis      F  1993-05-08
# 20045  28138297045  2024-01-02      Alexandria Kelly      F  1992-06-15
# 20046  28138477309  2024-01-02          Terry Nelson      M  1989-09-01
# 20047  28139432962  2024-01-02        Caleb Williams      M  1980-04-04
# 20048  28143079368  2024-01-02           Brian Berry      M  2000-12-25
#
#              PHONE                         EMAIL BLOOD_GRP  \
# 0      713-14-3771           candice51@gmail.com        B+
# 1      210-90-9630       anthonyberger@yahoo.com        A-
# 2      308-46-8467           ibenton@hotmail.com        B+
# 3      516-36-8579            yjohnson@gmail.com        A+
# 4      505-30-9519          rodneyowen@yahoo.com        B+
# ...            ...                           ...       ...
# 20044  738-05-1691        tiffanyestes@gmail.com        A-
# 20045  223-94-3662       adriennekeith@gmail.com       AB-
# 20046  039-01-9130          ssanchez@hotmail.com        B+
# 20047  690-80-0398        ashleymorris@gmail.com        B-
# 20048  360-32-6022  samanthamartinez@hotmail.com       AB+
#
#                                         JOB    OFFICE  \
# 0                          Industrial buyer   Seattle
# 1                      Merchandiser, retail  New York
# 2           Engineer, manufacturing systems  New York
# 3      Control and instrumentation engineer    Austin
# 4               Civil engineer, contracting    Austin
# ...                                     ...       ...
# 20044            Nurse, learning disability   Seattle
# 20045                 Management consultant  New York
# 20046                             Herbalist   Seattle
# 20047                Embryologist, clinical   Chicago
# 20048                    Professor Emeritus    Austin
#
#                                                  ADDRESS             ORG  \
# 0                       Unit 9731 Box 2082\nDPO AP 28599         Product
# 1      6510 Daniel Avenue Apt. 792\nAcostaburgh, TN 4...           Sales
# 2      26257 Lauren Parkway Apt. 289\nKathrynmouth, M...           Sales
# 3          3351 Christopher Meadow\nPort Scott, OK 40845          Devops
# 4      5995 Bonnie Lodge Apt. 893\nVelazquezmouth, MA...         Product
# ...                                                  ...             ...
# 20044  1226 Norma Walks Suite 388\nBrianaborough, WA ...  Internal Tools
# 20045       872 Miller Stravenue\nJeffreyshire, AK 62718           Sales
# 20046                       USCGC Williams\nFPO AA 14015         Product
# 20047       3516 Tracy Rapids\nNew Ronaldmouth, MD 15728          Devops
# 20048         6026 Jackson Lodge\nLake Abigail, OR 39017          Devops
#
#                  TITLE    SINCE_DT     SALARY     BONUS
# 0                   VP  2013-01-07  210000.00  40500.00
# 1            Associate  2011-08-01   79000.00  13500.00
# 2            Associate  2010-04-20   68000.00  13000.00
# 3      Senior Engineer  2021-06-22  129000.00  24000.00
# 4                   VP  2007-06-17  241000.00  45500.00
# ...                ...         ...        ...       ...
# 20044         Engineer  2019-05-02   98000.00  18500.00
# 20045        Associate  2014-06-10   63000.00  12000.00
# 20046          Manager  2016-08-25  150000.00  26000.00
# 20047  Senior Engineer  2017-03-26  130000.00  20500.00
# 20048  Senior Engineer  2020-12-20  119000.00  21000.00
#
# [20049 rows x 16 columns]

# %%
ch.get_existing_snap_dts()
# Out:
# [datetime.date(2024, 1, 1), datetime.date(2024, 1, 2)]

# %%
import pandas as pd
import numpy as np
from typing import List, Tuple, Dict
from datetime import date, datetime

# %%
ibis.dtype(np.dtype('int8'), nullable = True)
ibis.dtype(pd.Int16Dtype(), nullable = True)
ibis.dtype(List[str], nullable = False)
ibis.dtype(date, nullable = False)
ibis.dtype(datetime, nullable = False).to_pandas()
# Out:
# dtype('<M8[ns]')

# %%
ibis.dtype(ibis.expr.datatypes.Int32(nullable=True).to_pandas())
# Out:
# Int32(nullable=True)

# %%
ibis.expr.datatypes.Array(value_type = str, nullable = False).to_pyarrow()
# Out:
# ListType(list<item: string>)

# %%
from ibis import schema
from ibis.expr.datatypes import String, Timestamp, Array, Int32

schema(pairs = [
    ('name', String(nullable = False)),
    ('snap_dt', Timestamp(nullable = True, timezone = 'utc')),
    ('history', Array(nullable = False, value_type = Int32(nullable = False)))
])
# Out:
# ibis.Schema {
#   name     !string
#   snap_dt  timestamp('utc')
#   history  !array<!int32>
# }

# %%
tb = bq._ops.table(f"{bq.schema}.__TABLES__")
tb.filter(tb['table_id'] == bq.table).agg(size = tb['size_bytes'].sum()).to_pandas().loc[0, 'size']
# Out:
# 2034212

# %%
SnapshotDataManagerBQSQL.setup(db_conf=bq_conf)
bq = SnapshotDataManagerBQSQL(schema = 'tt', table = 'CUST', snap_dt_key = 'SNAP_DT')

# %%
from ibis import schema
from ibis.expr.datatypes import String, Timestamp, Array, Int32, Int64, Date, Decimal, Float32

schema_ = schema(pairs = [
    ('CUST_ID', Int64(nullable = False)),
    ('SNAP_DT', Date(nullable = False)),
    ('NAME', String(nullable = False)),
    ('GENDER', String(nullable = False)),
    ('BIRTH_DT', Date(nullable = True)),
    ('PHONE', String(nullable = True)),
    ('EMAIL', String(nullable = True)),
    ('BLOOD_GRP', String(nullable = True)),
    ('JOB', String(nullable = True)),
    ('OFFICE', String(nullable = True)),
    ('ADDRESS', String(nullable = True)),
    ('ORG', String(nullable = True)),
    ('TITLE', String(nullable = True)),
    ('SINCE_DT', Date(nullable = True)),
    ('SALARY', Float32(nullable = True)),
    ('BONUS', Float32(nullable = True)),
])

bq.init_table(
    col_schemas = schema_,
    cluster_keys = ['CUST_ID', 'SNAP_DT'],
    partition_keys = ['SNAP_DT']
)

# %%
from luntaiDs.ProviderTools.aws.s3 import S3Accessor

s3a = S3Accessor(
    aws_access_key_id='luntaixiaadmin',
    aws_secret_access_key='luntaixiaadmin',
    endpoint_url = 'http://tnas-3991.local:9000'
)
s3a.enter_bucket('general-clf-pipeline-project')

df = s3a.read_parquet("/fake/data/FEATURES/CUST/CUST_2024-01-01.parquet")
#bq.save(df, snap_dt=date(2024,1,1))

# %%
df.to_parquet("CUST_2024-01-01.parquet")

# %%
bq.delete(date(2024, 1, 1))

# %%
bq.duplicate('lla_pr', 'CUST_BK')

# %%
bq.disk_space(date(2024,1,1))
# Out:
# 1.9399757385253906

# %%
con.create_schema(
    name = 'RAW',
    force = True
)

# %%
con.read_parquet(
    source_list = "s3://model-serving-lambda/datas/CUST_2024-01-01.parquet",
    table_name = "CUST",
)
# Out:
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ NAME             ┃ GENDER ┃ PHONE       ┃ EMAIL                  ┃ BLOOD_GRP ┃ JOB                                 ┃ ADDRESS                                                   ┃ CUST_ID     ┃ OFFICE   ┃ ORG            ┃ TITLE           ┃ SALARY ┃ BONUS ┃ BIRTH_DT                  ┃ SINCE_DT                  ┃ SNAP_DT                   ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ string           │ string │ string      │ string                 │ string    │ string                              │ string                                                    │ int64       │ string   │ string         │ string          │ int64  │ int64 │ timestamp('UTC')          │ timestamp('UTC')          │ timestamp('UTC')          │
# ├──────────────────┼────────┼─────────────┼────────────────────────┼───────────┼─────────────────────────────────────┼───────────────────────────────────────────────────────────┼─────────────┼──────────┼────────────────┼─────────────────┼────────┼───────┼───────────────────────────┼───────────────────────────┼───────────────────────────┤
# │ Karen Noble      │ F      │ 654-36-4337 │ cchang@yahoo.com       │ A-        │ Dealer                              │ 4522 Mark Flat Suite 486\nWest Cherylfort, WA 43183       │ 10618301949 │ New York │ Sales          │ Associate       │  71000 │ 12500 │ 1976-09-13 00:00:00+00:00 │ 2005-09-06 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Bethany Conner   │ F      │ 667-36-2441 │ yflores@hotmail.com    │ B+        │ Fisheries officer                   │ 926 Brown Fort Apt. 491\nLake Johnport, VT 33247          │ 19543171408 │ Chicago  │ Devops         │ Manager         │ 132000 │ 24000 │ 1993-07-26 00:00:00+00:00 │ 2011-07-22 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Nicole Palmer    │ F      │ 329-48-8472 │ smithregina@yahoo.com  │ O-        │ Dramatherapist                      │ PSC 0376, Box 2792\nAPO AP 12988                          │ 20079016668 │ Austin   │ Devops         │ Manager         │ 138000 │ 22500 │ 1988-06-11 00:00:00+00:00 │ 2010-06-06 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Bonnie Brown     │ F      │ 365-94-2189 │ wendycarter@gmail.com  │ O+        │ Furniture designer                  │ 8666 Brian Spurs\nSmithfurt, MT 30880                     │ 13358946844 │ Austin   │ Internal Tools │ Manager         │ 130000 │ 24000 │ 1985-05-12 00:00:00+00:00 │ 2014-05-05 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Christina Gibbs  │ F      │ 493-19-9589 │ ksimmons@gmail.com     │ O-        │ Estate manager/land agent           │ 0012 Anderson Track Suite 169\nNew Anthonyshire, AK 93839 │ 20667141447 │ New York │ Sales          │ Associate       │  76000 │ 14500 │ 1970-03-02 00:00:00+00:00 │ 2005-02-21 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Dawn Melton      │ F      │ 510-68-8097 │ david27@gmail.com      │ AB+       │ Civil Service fast streamer         │ 97821 Sherry Flats Apt. 994\nSouth Amber, ME 21513        │ 24105472634 │ Chicago  │ Devops         │ Senior Engineer │ 125000 │ 24500 │ 2000-03-22 00:00:00+00:00 │ 2020-03-17 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Jeremy Fernandez │ M      │ 774-88-1590 │ jacqueline62@yahoo.com │ B+        │ Engineer, energy                    │ 68142 Jones Point Apt. 788\nMorrisonland, MH 39635        │ 15723031917 │ Seattle  │ Product        │ VP              │ 227000 │ 43000 │ 1972-07-22 00:00:00+00:00 │ 2011-07-13 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ John Fuentes     │ M      │ 784-02-8683 │ xbaker@yahoo.com       │ O-        │ Engineer, broadcasting (operations) │ 979 Diane Corner Apt. 583\nMorganhaven, CA 78529          │  8490947327 │ Chicago  │ Devops         │ Manager         │ 149000 │ 25000 │ 1967-03-25 00:00:00+00:00 │ 2004-03-15 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Tiffany Wiley    │ F      │ 792-53-7830 │ victoria27@gmail.com   │ B+        │ Site engineer                       │ 357 Vincent Shoal Apt. 888\nWest Sarahport, MP 21948      │  6707386915 │ Seattle  │ Internal Tools │ Senior Engineer │ 127000 │ 25000 │ 2002-01-28 00:00:00+00:00 │ 2022-01-23 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ Ashley Stewart   │ F      │ 111-16-5753 │ arnoldcindy@gmail.com  │ O-        │ Restaurant manager, fast food       │ 6578 Wells Bypass\nMichaelhaven, SC 97276                 │ 14118331675 │ New York │ Sales          │ Associate       │  76000 │ 12000 │ 1975-08-27 00:00:00+00:00 │ 2004-08-19 00:00:00+00:00 │ 2024-01-01 00:00:00+00:00 │
# │ …                │ …      │ …           │ …                      │ …         │ …                                   │ …                                                         │           … │ …        │ …              │ …               │      … │     … │ …                         │ …                         │ …                         │
# └──────────────────┴────────┴─────────────┴────────────────────────┴───────────┴─────────────────────────────────────┴───────────────────────────────────────────────────────────┴─────────────┴──────────┴────────────────┴─────────────────┴────────┴───────┴───────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
SnapshotDataManagerDuckSQL.setup(duck_path = '/home/luntaixia/Downloads/docker-volume-mapping/playground/duckdb/test.db',)
duck = SnapshotDataManagerDuckSQL(schema = 'tt', table = 'CUST', snap_dt_key = 'SNAP_DT')

# %%
from ibis import schema
from ibis.expr.datatypes import String, Timestamp, Array, Int32, Int64, Date, Decimal, Float32

schema_ = schema(pairs = [
    ('CUST_ID', Int64(nullable = False)),
    ('SNAP_DT', Date(nullable = False)),
    ('NAME', String(nullable = False)),
    ('GENDER', String(nullable = False)),
    ('BIRTH_DT', Date(nullable = True)),
    ('PHONE', String(nullable = True)),
    ('EMAIL', String(nullable = True)),
    ('BLOOD_GRP', String(nullable = True)),
    ('JOB', String(nullable = True)),
    ('OFFICE', String(nullable = True)),
    ('ADDRESS', String(nullable = True)),
    ('ORG', String(nullable = True)),
    ('TITLE', String(nullable = True)),
    ('SINCE_DT', Date(nullable = True)),
    ('SALARY', Float32(nullable = True)),
    ('BONUS', Float32(nullable = True)),
])

duck.init_table(
    col_schemas = schema_,
)
# Out:
# WARNING:root:tt.CUST already exists, will do nothing.set overwrite to True if you wish to reset table

# %%
duck._ops.list_schemas()
# Out:
# ['information_schema', 'main', 'pg_catalog', 'tt']

# %%
duck._ops.list_tables(schema = 'main')
# Out:
# ['CUST']

# %%
duck._ops.current_database
# Out:
# 'test'

# %%
duck._ops.list_schemas()
# Out:
# ['information_schema', 'main', 'pg_catalog', 'tt']

# %%
duck._ops.list_tables(schema = 'test')
# Out:
# []

# %%
import ibis

# %%
getattr(ibis.expr.datatypes, "Date")(nullable = False)
# Out:
# Date(nullable=False)

# %%
from ibis import schema

def extract_dtype(dtype: str, args: dict) -> ibis.expr.datatypes.DataType:
    if dtype == 'Array':
        value_type = args.pop('value_type')
        value_dtype = extract_dtype(value_type['dtype'], value_type['args'])
        return ibis.expr.datatypes.Array(
            value_type = value_dtype,
            **args
        )
    elif dtype == 'Map':
        key_type = args.pop('key_type')
        key_dtype = extract_dtype(key_type['dtype'], key_type['args'])
        value_type = args.pop('value_type')
        value_dtype = extract_dtype(value_type['dtype'], value_type['args'])
        return ibis.expr.datatypes.Map(
            key_type = key_dtype,
            value_type = value_dtype,
            **args
        )
    elif dtype == 'Struct':
        fields = args.pop("fields")
        fields_dtype = dict()
        for k, v in fields.items():
            v_dtype = extract_dtype(v['dtype'], v['args'])
            fields_dtype[k] = v_dtype
        return ibis.expr.datatypes.Struct(
            fields = fields_dtype,
            **args
        )
    else:
        return getattr(ibis.expr.datatypes, dtype)(**args)


def create_schema_from_dtype_dict(schema_dict: dict) -> schema:
    """generate ibis schema from schema dictonary
    ref: https://ibis-project.org/reference/datatypes#ibis.expr.datatypes.core.Timestamp

    :param dict schema_dict: column-dtype pair, support Array/Map/Struct, example:
        ```json
        {
            "CUST_ID":{
                "dtype":"Int32",
                "args":{
                "nullable":false
                }
            },
            "SNAP_DT":{
                "dtype":"Date",
                "args":{
                "nullable":true
                }
            },
            "SAMPLE_ARRAY":{
                "dtype":"Array",
                "args":{
                "value_type":{
                    "dtype":"String",
                    "args":{
                    "nullable":false
                    }
                },
                "nullable":false
                }
            },
            "SAMPLE_MAP":{
                "dtype":"Map",
                "args":{
                "key_type":{
                    "dtype":"String",
                    "args":{
                    "nullable":false
                    }
                },
                "value_type":{
                    "dtype":"Float64",
                    "args":{
                    "nullable":false
                    }
                },
                "nullable":false
                }
            },
            "SAMPLE_NESTED":{
                "dtype":"Array",
                "args":{
                "value_type":{
                    "dtype":"Map",
                    "args":{
                    "key_type":{
                        "dtype":"String",
                        "args":{
                        "nullable":false
                        }
                    },
                    "value_type":{
                        "dtype":"Int64",
                        "args":{
                        "nullable":true
                        }
                    },
                    "nullable":false
                    }
                },
                "nullable":false
                }
            },
            "SAMPLE_STRUCT":{
                "dtype":"Struct",
                "args":{
                "fields":{
                    "id":{
                    "dtype":"Int8",
                    "args":{
                        "nullable":false
                    }
                    },
                    "trans_dt":{
                    "dtype":"Timestamp",
                    "args":{
                        "timezone":"UTC",
                        "nullable":false
                    }
                    },
                    "amount":{
                    "dtype":"Decimal",
                    "args":{
                        "precision":10,
                        "scale":2,
                        "nullable":false
                    }
                    }
                },
                "nullable":false
                }
            }
        }
        ```
    :return schema: ibis schema
    """
    sh = []
    for col, s in schema_dict.items():
        dtype = extract_dtype(s['dtype'], s['args'])
        sh.append(
            (col, dtype)
        )
        
    return schema(pairs = sh)

ibis_schema = create_schema_from_dtype_dict(schemas)

# %%
con = ibis.clickhouse.connect(
    user='luntaixia',
    password='luntaixia',
    host='localhost',
    port=8123,
    settings = {
        'join_use_nulls' : 1
    }
)
# con.create_database('test', force = True)
# con.create_table(
#     name = 'sample',
#     schema = ibis_schema,
#     database = 'test',
#     engine = 'MergeTree',
# )

# %%
ibis.expr.datatypes.Struct(fields = {
    'id' : ibis.expr.datatypes.Int8(nullable = False),
    'trans_dt' : ibis.expr.datatypes.Timestamp(timezone = 'UTC', nullable = False),
    'amount' : ibis.expr.datatypes.Decimal(precision = 10, scale = 2)
})
# Out:
# 'Struct([('id', Int8(nullable=False)), ('trans_dt', Timestamp(timezone='UTC', scale=None, nullable=False)), ('amount', Decimal(precision=10, scale=2, nullable=True))], nullable=True)

# %%
ibis.expr.datatypes.Map(key_type = ibis.expr.datatypes.String(nullable = False), value_type = ibis.expr.datatypes.Float16(nullable = False), nullable = True)
# Out:
# Map(key_type=String(nullable=False), value_type=Float16(nullable=False), nullable=True)

# %%
ibis.expr.datatypes.Array(value_type = ibis.expr.datatypes.Float16(nullable = False), nullable = True)
# Out:
# Array(value_type=Float16(nullable=False), nullable=True)

# %%
for k, v in ibis_schema.items():
    print(k, v)
    print(v.name, v.nullable)
# Out:
# CUST_ID !int32
# Int32 False
# SNAP_DT date
# Date True

# %%
import logging
from dataclasses import dataclass, asdict
from dacite import from_dict
from collections import OrderedDict
from enum import Enum
from typing import Dict, List, Any, Optional
import yaml
import numpy as np
import ibis
from ibis import schema

# %%
from luntaiDs.CommonTools.dtyper import DSchema

# %%
file = """
{
    "CUST_ID" : {
        "dtype":"Int64",
        "args":{
            "nullable": false
        },
        "descr" : "customer id",
        "primary_key" : true
    },
    "SNAP_DT" : {
        "dtype":"Date",
        "args":{
            "nullable": false
        },
        "descr" : "observation snapshot date",
        "primary_key" : true
    },
    "NAME" : {
        "dtype":"String",
        "args":{
            "nullable": false
        },
        "descr" : "first and last name",
        "primary_key" : false
    },
    "GENDER" : {
        "dtype":"String",
        "args":{
            "nullable": false
        },
        "descr" : "Male (M) or Female (F)",
        "primary_key" : false
    },
    "BIRTH_DT" : {
        "dtype":"Date",
        "args":{
            "nullable": true
        },
        "descr" : "birthday",
        "primary_key" : false
    },
    "PHONE" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "telephone number",
        "primary_key" : false
    },
    "EMAIL" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "email",
        "primary_key" : false
    },
    "BLOOD_GRP" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "blood group (A+, A-, O, etc.)",
        "primary_key" : false
    },
    "JOB" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "occupation",
        "primary_key" : false
    },
    "OFFICE" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "city of the office",
        "primary_key" : false
    },
    "ADDRESS" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "detailed address",
        "primary_key" : false
    },
    "ORG" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "organization",
        "primary_key" : false
    },
    "TITLE" : {
        "dtype":"String",
        "args":{
            "nullable": true
        },
        "descr" : "title of the position",
        "primary_key" : false
    },
    "SINCE_DT" : {
        "dtype":"Date",
        "args":{
            "nullable": true
        },
        "descr" : "the start date at current company",
        "primary_key" : false
    },
    "SALARY" : {
        "dtype":"Decimal",
        "args":{
            "precision" : 10,
            "scale" : 2,
            "nullable" : false
        },
        "descr" : "base salary in dollar amount",
        "primary_key" : false
    },
    "BONUS" : {
        "dtype":"Decimal",
        "args":{
            "precision" : 10,
            "scale" : 2,
            "nullable" : false
        },
        "descr" : "bonus in dollar amount",
        "primary_key" : false
    }
}
"""

# %%
import json

s = json.loads(file)

# %%
ds = DSchema.from_js(s)

# %%
ds['GENDER']
# Out:
# DSchemaField(dtype='String', args={'nullable': False}, primary_key=False, descr='Male (M) or Female (F)', extra_kws=None)

# %%
import pymongo

conn_str = f"mongodb://rootuser:rootpass@localhost:27017/"
conn = pymongo.MongoClient(conn_str)

# %%
from luntaiDs.ProviderTools.mongo.schema_manager import MongoSchemaManager

msm = MongoSchemaManager(mongo_client=conn, database='table_schema_ch', collection='schemas')

# %%
col_schemas = msm.read('RAW', 'CUSTOMER')

# %%
primary_keys = col_schemas.primary_keys
partition_keys = col_schemas.partition_keys
if 'SNAP_DT' not in partition_keys:
    partition_keys.append('SNAP_DT')

# %%
primary_keys
# Out:
# ['CUST_ID', 'SNAP_DT']

# %%
partition_keys
# Out:
# ['SNAP_DT']

# %%
con.create_table(
    name = 'CUSTOMER',
    schema = col_schemas.ibis_schema,
    database = 'RAW',
    engine = "MergeTree",
    order_by = primary_keys,
    partition_by = partition_keys,
    settings = {}
)
# Out:
# ┏━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ CUST_ID ┃ SNAP_DT ┃ NAME    ┃ GENDER  ┃ BIRTH_DT ┃ PHONE  ┃ EMAIL  ┃ BLOOD_GRP ┃ JOB    ┃ OFFICE ┃ ADDRESS ┃ ORG    ┃ TITLE  ┃ SINCE_DT ┃ SALARY          ┃ BONUS           ┃
# ┡━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ !int64  │ !date   │ !string │ !string │ date     │ string │ string │ string    │ string │ string │ string  │ string │ string │ date     │ !decimal(10, 2) │ !decimal(10, 2) │
# └─────────┴─────────┴─────────┴─────────┴──────────┴────────┴────────┴───────────┴────────┴────────┴─────────┴────────┴────────┴──────────┴─────────────────┴─────────────────┘

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import json

with open('/home/luntaixia/Documents/general-clf-pipeline-deploy/pipeline/schemas/RAW/ACCOUNTS.json') as obj:
    content = json.load(obj)

# %%
from luntaiDs.CommonTools.schema_manager import LocalSchemaManager

lsm = LocalSchemaManager(root_dir = '/home/luntaixia/Downloads/test')
lsm.write_raw('RAW', 'CUSTOMER', content)

# %%
from luntaiDs.CommonTools.schema_manager import ObjStorageSchemaManager

osm = ObjStorageSchemaManager(s3a, bucket = 'general-clf-pipeline-project', root_dir = '/data')

# %%
osm.write_raw('RAW', 'CUSTOMER', content)

# %%
osm.read('RAW', 'CUSTOMER').ibis_schema
# Out:
# ibis.Schema {
#   CUST_ID       !int64
#   ACCT_ID       !string
#   SNAP_DT       !date
#   ACCT_TYPE_CD  !string
#   END_BAL       !decimal(12, 2)
#   DR_AMT        !decimal(12, 2)
#   CR_AMT        !decimal(12, 2)
#   CR_LMT        !decimal(12, 2)
# }

# %%
from luntaiDs.ProviderTools.ssh.sftp import SFTP

sf = SFTP(
    host = 'xxx',
    port = 9333,
    username = 'xxx',
    password = 'xxx'
)

# %%
from luntaiDs.ProviderTools.ssh.schema_manager import SFTPSchemaManager

ssm = SFTPSchemaManager(sf, root_dir='/public-raid0/file-share/random/test-schema')

# %%
ssm.write_raw('RAW', 'CUSTOMER', content)

# %%
ssm.read('RAW', 'CUSTOMER').ibis_schema
# Out:
# ibis.Schema {
#   CUST_ID       !int64
#   ACCT_ID       !string
#   SNAP_DT       !date
#   ACCT_TYPE_CD  !string
#   END_BAL       !decimal(12, 2)
#   DR_AMT        !decimal(12, 2)
#   CR_AMT        !decimal(12, 2)
#   CR_LMT        !decimal(12, 2)
# }
